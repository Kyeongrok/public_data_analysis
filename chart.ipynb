# %%
import matplotlib.pyplot as plt

x = [1, 2, 3]
y = [2, 3, 4]
z = [100, 50, 0]

plt.subplot(1, 2, 1)
plt.title('xxx')
plt.bar(x, y)
# plt.plot(x, y)
plt.subplot(1, 2, 2)
plt.title('yyy')
plt.bar(x, z, color='r')

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
plt.title('x, y, z')
# fig.set_size_inches([5, 5])
ax1.bar(x, y, color='g')
ax2.plot(x, z, color='r')
